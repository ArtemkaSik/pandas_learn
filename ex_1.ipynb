# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv', encoding='1251')

# %%
df.head(3)
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-11  10:15:35     2173  2004598       2   22577
# 1  2022-08-11  10:27:46     2174  2004598       2   22577
# 2  2022-08-11  10:27:46     2174  2004598       2   22577
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18      45399
# 1  Розничная реализация       15     261519
# 2  Розничная реализация       15     460864
#
#                                            DR_NDrugs        DR_Suppl  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...  Катрен г.Химки
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.  Катрен г.Химки
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...  Катрен г.Химки
#
#                                     DR_Prod  DR_Kol  DR_CZak  DR_CRoz  \
# 0  Д-р Редди с Лабораторис Лтд / Dr.REDDY's    1.00    41.08    51.00
# 1                         ФЛОРА КАВКАЗА ОАО    1.00    18.61    31.00
# ...

# %%
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller than the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# ...

# %%
pd.set_option('display.max_columns', 40)

pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.dtypes
# Out:
# DR_Dat            str
# DR_Tim            str
# DR_NChk         int64
# DR_NDoc         int64
# DR_Apt          int64
# DR_Kkm          int64
# DR_TDoc           str
# DR_TPay         int64
# DR_CDrugs       int64
# DR_NDrugs         str
# DR_Suppl          str
# DR_Prod           str
# DR_Kol        float64
# DR_CZak       float64
# DR_CRoz       float64
# DR_SDisc      float64
# DR_CDisc      float64
# DR_BCDisc     float64
# DR_TabEmpl      int64
# DR_VZak         int64
# DR_Pos        float64
# dtype: object

# %%
print(df.shape)

print(df.size)

print(df.index)

print(df.columns)
# Out:
# (4462, 21)
# 93702
# RangeIndex(start=0, stop=4462, step=1)
# Index(['DR_Dat', 'DR_Tim', 'DR_NChk', 'DR_NDoc', 'DR_Apt', 'DR_Kkm', 'DR_TDoc',
#        'DR_TPay', 'DR_CDrugs', 'DR_NDrugs', 'DR_Suppl', 'DR_Prod', 'DR_Kol',
#        'DR_CZak', 'DR_CRoz', 'DR_SDisc', 'DR_CDisc', 'DR_BCDisc', 'DR_TabEmpl',
#        'DR_VZak', 'DR_Pos'],
#       dtype='str')

# %%
our_cols = ['DR_Dat', 'DR_Tim', 'DR_NChk', 'DR_NDoc', 'DR_Apt', 'DR_NDrugs', 'DR_Kol',
       'DR_CZak', 'DR_CRoz', 'DR_SDisc', 'DR_TPay', 'DR_CDrugs', 'DR_Suppl', 'DR_CDisc', 'DR_BCDisc', 'DR_TabEmpl', 'DR_VZak', 'DR_Pos']

# %%
df = df[our_cols]

# %%
df.head(3)
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  \
# 0  2022-08-11  10:15:35     2173  2004598       2
# 1  2022-08-11  10:27:46     2174  2004598       2
# 2  2022-08-11  10:27:46     2174  2004598       2
#
#                                            DR_NDrugs  DR_Kol  DR_CZak  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...    1.00    41.08
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.    1.00    18.61
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...    1.00   132.69
#
#    DR_CRoz  DR_SDisc  DR_TPay  DR_CDrugs        DR_Suppl  DR_CDisc  \
# 0    51.00     12.00       18      45399  Катрен г.Химки    925.00
# 1    31.00      3.00       15     261519  Катрен г.Химки      9.00
# 2   209.00     20.00       15     460864  Катрен г.Химки      9.00
#
#         DR_BCDisc  DR_TabEmpl  DR_VZak  DR_Pos
# 0 200000000492.00         205        1    1.00
# 1 200010010204.00         205        1    1.00
# 2 200010010204.00         205        1    2.00

# %%
print(df.size)
# Out:
# 80316

# %%
df.columns = [
    'c_date', 'c_time', 'nchk', 'ndoc', 'apt', 'drug', 'kol',
    'zak', 'roz', 'discount', 'pay_type', 'drug_id', 'suppl', 'disc_id',
    'disc_barcode', 'empl', 'vzak', 'pos'
]

# %%
df.dtypes
# Out:
# c_date              str
# c_time              str
# nchk              int64
# ndoc              int64
# apt               int64
# drug                str
# kol             float64
# zak             float64
# roz             float64
# discount        float64
# pay_type          int64
# drug_id           int64
# suppl               str
# disc_id         float64
# disc_barcode    float64
# empl              int64
# vzak              int64
# pos             float64
# dtype: object

# %%
pd.to_datetime(df['c_date']).dt.year
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 4457    2022
# 4458    2022
# 4459    2022
# 4460    2022
# 4461    2022
# Name: c_date, Length: 4462, dtype: int32

# %%
df['c_date'] = pd.to_datetime(df['c_date']).dt.strftime('%d.%m.%Y')

# %%
df['vzak'].unique()
# Out:
# array([1, 2])

# %%
df['vzak'].astype('str').replace('1', 'Обычный').replace('2', 'Интернет').unique()
# Out:
# <StringArray>
# ['Обычный', 'Интернет']
# Length: 2, dtype: str

# %%
df['vzak'] = df['vzak'].astype('str').replace('1', 'Обычный').replace('2', 'Интернет')

# %%
df.isna().any()
# Out:
# c_date          False
# c_time          False
# nchk            False
# ndoc            False
# apt             False
# drug            False
# kol             False
# zak             False
# roz             False
# discount        False
# pay_type        False
# drug_id         False
# suppl           False
# disc_id          True
# disc_barcode     True
# empl            False
# vzak            False
# pos             False
# dtype: bool

# %%
dfna = df[df.isna().values.any(axis=1)]

# %%
dfna.fillna(0).head(5)
# Out:
#         c_date    c_time  nchk     ndoc  apt  \
# 15  11.08.2022  11:00:23  2178  2004598    2
# 16  11.08.2022  11:00:23  2178  2004598    2
# 20  11.08.2022  11:31:34  2181  2004598    2
# 21  11.08.2022  11:31:34  2181  2004598    2
# 22  11.08.2022  11:36:05  2182  2004598    2
#
#                                                 drug  kol    zak    roz  \
# 15  НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/ 1.00  12.94  18.00
# 16  НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/ 1.00  12.94  18.00
# 20                     ЛАКТОФИЛЬТРУМ 500МГ. №60 ТАБ. 1.00 408.63 560.00
# 21                                  ФЕСТАЛ №40 ДРАЖЕ 1.00 333.74 458.00
# 22                    ДОКТОР МОМ №20 ПАСТИЛКИ МАЛИНА 1.00 141.55 200.00
#
#     discount  pay_type  drug_id              suppl  disc_id  disc_barcode  \
# 15      0.00        18   496504     Катрен г.Химки     0.00          0.00
# 16      0.00        18   496504     Катрен г.Химки     0.00          0.00
# ...

# %%
df['disc_id'].interpolate(method='linear')
# Out:
# 0      925.00
# 1        9.00
# 2        9.00
# 3        9.00
# 4      925.00
#         ...
# 4457     9.00
# 4458     9.00
# 4459     9.00
# 4460     9.00
# 4461     9.00
# Name: disc_id, Length: 4462, dtype: float64
